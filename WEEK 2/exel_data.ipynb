# %%
import pandas as pd
df = pd.read_csv("/content/Untitled spreadsheet - Sheet1.csv")
df.head()
# Out:
#          name  age       roll_no
# 0   vaishnavi    20  25wh1a054bl
# 1  nivarshika    19   25wh1a05bk
# 2     shravya    19   25wh1a05bm
# 3      hasini    19   25wh1a05bc
# 4       divya    20   25wh1a05bd
