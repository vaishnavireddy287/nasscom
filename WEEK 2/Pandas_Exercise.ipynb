# %%
import pandas as pd
import numpy as np

print("--- Intermediate Pandas Exercise ---")
print("Complete each task by writing the requested Pandas code.")
print("------------------------------------")

# Task 1: Basic Pandas Functions and Converting Arrays to DataFrames
print("\n--- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---")

# 1.1 Create a Pandas Series
s1_1 = pd.Series([10, 20, 30, 40, 50])

# 1.2 Create a 3x4 NumPy array with random integers
np_array1_2 = np.random.randint(1, 101, size=(3, 4))

# 1.3 Convert the array into a DataFrame
df1_3 = pd.DataFrame(np_array1_2, columns=['A', 'B', 'C', 'D'])

print("Series:")
print(s1_1)

print("\nNumPy Array:")
print(np_array1_2)

print("\nDataFrame:")
print(df1_3)


# Task 2: Synthetic Data Generation for Practice
print("\n--- Task 2: Synthetic Data Generation for Practice ---")

# Create DataFrame
df_sales = pd.DataFrame({
    'Date': pd.date_range('2023-01-01', periods=100),
    'Region': np.random.choice(['East', 'West', 'North', 'South'], 100),
    'Product': np.random.choice(['Laptop', 'Mouse', 'Keyboard', 'Monitor'], 100),
    'Sales': np.random.randint(100, 1001, 100).astype(float),
    'Quantity': np.random.randint(1, 11, 100).astype(float)
})

# Introduce NaN values
sales_nan = np.random.choice(df_sales.index, 5, replace=False)
qty_nan = np.random.choice(df_sales.index, 3, replace=False)

df_sales.loc[sales_nan, 'Sales'] = np.nan
df_sales.loc[qty_nan, 'Quantity'] = np.nan

print(df_sales.head())


# Task 3: Indexing and Slicing in DataFrames
print("\n--- Task 3: Indexing and Slicing in DataFrames ---")

# 3.1 Select Region and Sales columns
df3_1 = df_sales[['Region', 'Sales']]

# 3.2 Rows where Product is Laptop
df3_2 = df_sales[df_sales['Product'] == 'Laptop']

# 3.3 Region is East and Sales > 500
df3_3 = df_sales[
    (df_sales['Region'] == 'East') &
    (df_sales['Sales'] > 500)
]

# 3.4 Sales value for first Monitor entry
monitor_index = df_sales[df_sales['Product'] == 'Monitor'].index[0]
val3_4 = df_sales.loc[monitor_index, 'Sales']

print("\ndf3_1:")
print(df3_1.head())

print("\ndf3_2:")
print(df3_2.head())

print("\ndf3_3:")
print(df3_3.head())

print("\nFirst Monitor Sales:", val3_4)


# Task 4: Data Cleaning (Handling Missing Values)
print("\n--- Task 4: Data Cleaning (Handling Missing Values) ---")

# 4.1 Count missing values
missing_counts4_1 = df_sales.isnull().sum()

# 4.2 Fill missing Sales with mean
df4_2_filled = df_sales.copy()
mean_sales = df4_2_filled['Sales'].mean()
df4_2_filled['Sales'] = df4_2_filled['Sales'].fillna(mean_sales)

# 4.3 Drop rows containing any NaN
df4_3_dropped = df_sales.dropna()

print("Missing Values:")
print(missing_counts4_1)

print("\nSales column after filling NaNs:")
print(df4_2_filled.head())

print("\nData after dropping NaNs:")
print(df4_3_dropped.head())


# Task 5: Data Manipulation (Columns, Sorting, Grouping)
print("\n--- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---")

# 5.1 Create Total_Revenue
df_sales['Total_Revenue'] = df_sales['Sales'] * df_sales['Quantity']

# 5.2 Sort by Date ascending and Sales descending
df5_2_sorted = df_sales.sort_values(
    by=['Date', 'Sales'],
    ascending=[True, False]
)

# 5.3 Group by Region
df5_3_grouped_region = df_sales.groupby('Region')[['Sales', 'Quantity']].sum()

# 5.4 Group by Product
df5_4_grouped_product = df_sales.groupby('Product')['Sales'].mean()

print("\nData with Total_Revenue:")
print(df_sales.head())

print("\nSorted Data:")
print(df5_2_sorted.head())

print("\nGrouped by Region:")
print(df5_3_grouped_region)

print("\nAverage Sales by Product:")
print(df5_4_grouped_product)
# Out:
# --- Intermediate Pandas Exercise ---
# Complete each task by writing the requested Pandas code.
# ------------------------------------
#
# --- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---
# Series:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
#
# NumPy Array:
# [[72 44 71 77]
#  [90 91 21 61]
#  [34 42 28 89]]
#
# DataFrame:
#     A   B   C   D
# 0  72  44  71  77
# 1  90  91  21  61
# 2  34  42  28  89
#
# --- Task 2: Synthetic Data Generation for Practice ---
#         Date Region   Product  Sales  Quantity
# 0 2023-01-01  North  Keyboard  898.0       1.0
# 1 2023-01-02  South    Laptop  914.0       8.0
# 2 2023-01-03   West     Mouse  407.0       4.0
# 3 2023-01-04   West  Keyboard  194.0       1.0
# 4 2023-01-05   West   Monitor  661.0       3.0
#
# --- Task 3: Indexing and Slicing in DataFrames ---
#
# df3_1:
#   Region  Sales
# 0  North  898.0
# 1  South  914.0
# 2   West  407.0
# 3   West  194.0
# 4   West  661.0
#
# df3_2:
#          Date Region Product  Sales  Quantity
# 1  2023-01-02  South  Laptop  914.0       8.0
# 5  2023-01-06  South  Laptop  565.0       4.0
# 8  2023-01-09  South  Laptop  122.0       8.0
# 21 2023-01-22   West  Laptop  256.0      10.0
# 22 2023-01-23  North  Laptop    NaN       3.0
#
# df3_3:
#          Date Region   Product  Sales  Quantity
# 13 2023-01-14   East   Monitor  652.0       1.0
# 17 2023-01-18   East     Mouse  620.0       3.0
# 24 2023-01-25   East  Keyboard  633.0       2.0
# 30 2023-01-31   East   Monitor  627.0       5.0
# 39 2023-02-09   East    Laptop  869.0       5.0
#
# First Monitor Sales: 661.0
#
# --- Task 4: Data Cleaning (Handling Missing Values) ---
# Missing Values:
# Date        0
# Region      0
# Product     0
# Sales       5
# Quantity    3
# dtype: int64
#
# Sales column after filling NaNs:
#         Date Region   Product  Sales  Quantity
# 0 2023-01-01  North  Keyboard  898.0       1.0
# 1 2023-01-02  South    Laptop  914.0       8.0
# 2 2023-01-03   West     Mouse  407.0       4.0
# 3 2023-01-04   West  Keyboard  194.0       1.0
# 4 2023-01-05   West   Monitor  661.0       3.0
#
# Data after dropping NaNs:
#         Date Region   Product  Sales  Quantity
# 0 2023-01-01  North  Keyboard  898.0       1.0
# 1 2023-01-02  South    Laptop  914.0       8.0
# 2 2023-01-03   West     Mouse  407.0       4.0
# 3 2023-01-04   West  Keyboard  194.0       1.0
# 4 2023-01-05   West   Monitor  661.0       3.0
#
# --- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---
#
# Data with Total_Revenue:
#         Date Region   Product  Sales  Quantity  Total_Revenue
# 0 2023-01-01  North  Keyboard  898.0       1.0          898.0
# 1 2023-01-02  South    Laptop  914.0       8.0         7312.0
# 2 2023-01-03   West     Mouse  407.0       4.0         1628.0
# 3 2023-01-04   West  Keyboard  194.0       1.0          194.0
# 4 2023-01-05   West   Monitor  661.0       3.0         1983.0
#
# Sorted Data:
#         Date Region   Product  Sales  Quantity  Total_Revenue
# 0 2023-01-01  North  Keyboard  898.0       1.0          898.0
# 1 2023-01-02  South    Laptop  914.0       8.0         7312.0
# 2 2023-01-03   West     Mouse  407.0       4.0         1628.0
# 3 2023-01-04   West  Keyboard  194.0       1.0          194.0
# 4 2023-01-05   West   Monitor  661.0       3.0         1983.0
#
# Grouped by Region:
#           Sales  Quantity
# Region
# East    11880.0      83.0
# North   11814.0     110.0
# South   12675.0     147.0
# West    17654.0     181.0
#
# Average Sales by Product:
# Product
# Keyboard    519.500000
# Laptop      581.578947
# Monitor     568.235294
# Mouse       611.200000
# Name: Sales, dtype: float64
